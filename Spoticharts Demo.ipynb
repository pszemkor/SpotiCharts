# %%
from spoticharts import SpotiCharts
from datetime import date

# %%
sc = SpotiCharts()
# Out:
# 2021-03-30 22:06:14,280 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-03-30 22:06:14,281 INFO sqlalchemy.engine.base.Engine ()
# 2021-03-30 22:06:14,282 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-03-30 22:06:14,282 INFO sqlalchemy.engine.base.Engine ()

# %%
df = sc.get_all_viral(country_codes=['us', 'pl'], start_date=date(2019,1,1))
# Out:
# 2021-03-30 22:06:41,643 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-03-30 22:06:41,645 INFO sqlalchemy.engine.base.Engine SELECT "Viral50".id AS "Viral50_id", "Viral50".spotify_id AS "Viral50_spotify_id", "Viral50".date AS "Viral50_date", "Viral50".region AS "Viral50_region", "Viral50".position AS "Viral50_position", "Viral50".track_name AS "Viral50_track_name", "Viral50".artist AS "Viral50_artist"
# FROM "Viral50"
# WHERE "Viral50".region IN (?, ?) AND "Viral50".date >= ?
# 2021-03-30 22:06:41,646 INFO sqlalchemy.engine.base.Engine ('us', 'pl', '2019-01-01')
# 2021-03-30 22:06:43,525 INFO sqlalchemy.engine.base.Engine ROLLBACK
# 2021-03-30 22:06:43,670 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-03-30 22:06:43,671 INFO sqlalchemy.engine.base.Engine SELECT "AudioFeatures".id AS "AudioFeatures_id", "AudioFeatures".danceability AS "AudioFeatures_danceability", "AudioFeatures".energy AS "AudioFeatures_energy", "AudioFeatures".loudness AS "AudioFeatures_loudness", "AudioFeatures".speechiness AS "AudioFeatures_speechiness", "AudioFeatures".acousticness AS "AudioFeatures_acousticness", "AudioFeatures".instrumentalness AS "AudioFeatures_instrumentalness", "AudioFeatures".liveness AS "AudioFeatures_liveness", "AudioFeatures".valence AS "AudioFeatures_valence", "AudioFeatures".tempo AS "AudioFeatures_tempo", "AudioFeatures".duration_ms AS "AudioFeatures_duration_ms"
# FROM "AudioFeatures"
# 2021-03-30 22:06:43,672 INFO sqlalchemy.engine.base.Engine ()
# 2021-03-30 22:06:47,060 INFO sqlalchemy.engine.base.Engine ROLLBACK

# %%
df.head()
# Out:
#         artist  position        date  \
# 0  Mark Ronson         1  2019-01-03
# 1  Mark Ronson         1  2019-01-05
# 2  Mark Ronson         1  2019-01-06
# 3  Mark Ronson         2  2019-01-11
# 4  Mark Ronson         2  2019-01-12
#
#                                         track_name region  \
# 0  Nothing Breaks Like a Heart (feat. Miley Cyrus)     pl
# 1  Nothing Breaks Like a Heart (feat. Miley Cyrus)     pl
# 2  Nothing Breaks Like a Heart (feat. Miley Cyrus)     pl
# 3  Nothing Breaks Like a Heart (feat. Miley Cyrus)     pl
# 4  Nothing Breaks Like a Heart (feat. Miley Cyrus)     pl
#
#                spotify_id  speechiness  energy    tempo  liveness  \
# 0  27rdGxbavYJeBphck5MZAF       0.0671   0.794  114.066     0.388
# 1  27rdGxbavYJeBphck5MZAF       0.0671   0.794  114.066     0.388
# 2  27rdGxbavYJeBphck5MZAF       0.0671   0.794  114.066     0.388
# 3  27rdGxbavYJeBphck5MZAF       0.0671   0.794  114.066     0.388
# 4  27rdGxbavYJeBphck5MZAF       0.0671   0.794  114.066     0.388
#
#    acousticness  loudness  danceability  duration_ms  valence  \
# 0       0.00987    -5.844         0.601       217467    0.244
# 1       0.00987    -5.844         0.601       217467    0.244
# 2       0.00987    -5.844         0.601       217467    0.244
# 3       0.00987    -5.844         0.601       217467    0.244
# 4       0.00987    -5.844         0.601       217467    0.244
#
#    instrumentalness
# 0          0.000001
# 1          0.000001
# 2          0.000001
# 3          0.000001
# 4          0.000001

# %%
print(len(df))
df.head()
# Out:
# 66800
#         artist  position        date  \
# 0  Mark Ronson         1  2019-01-03
# 1  Mark Ronson         1  2019-01-05
# 2  Mark Ronson         1  2019-01-06
# 3  Mark Ronson         2  2019-01-11
# 4  Mark Ronson         2  2019-01-12
#
#                                         track_name region  \
# 0  Nothing Breaks Like a Heart (feat. Miley Cyrus)     pl
# 1  Nothing Breaks Like a Heart (feat. Miley Cyrus)     pl
# 2  Nothing Breaks Like a Heart (feat. Miley Cyrus)     pl
# 3  Nothing Breaks Like a Heart (feat. Miley Cyrus)     pl
# 4  Nothing Breaks Like a Heart (feat. Miley Cyrus)     pl
#
#                spotify_id  speechiness  energy    tempo  liveness  \
# 0  27rdGxbavYJeBphck5MZAF       0.0671   0.794  114.066     0.388
# 1  27rdGxbavYJeBphck5MZAF       0.0671   0.794  114.066     0.388
# 2  27rdGxbavYJeBphck5MZAF       0.0671   0.794  114.066     0.388
# 3  27rdGxbavYJeBphck5MZAF       0.0671   0.794  114.066     0.388
# 4  27rdGxbavYJeBphck5MZAF       0.0671   0.794  114.066     0.388
#
#    acousticness  loudness  danceability  duration_ms  valence  \
# 0       0.00987    -5.844         0.601       217467    0.244
# 1       0.00987    -5.844         0.601       217467    0.244
# 2       0.00987    -5.844         0.601       217467    0.244
# 3       0.00987    -5.844         0.601       217467    0.244
# 4       0.00987    -5.844         0.601       217467    0.244
#
#    instrumentalness
# 0          0.000001
# 1          0.000001
# 2          0.000001
# 3          0.000001
# 4          0.000001

# %%
df = sc.get_all_top_200(country_codes=['us', 'pl'], start_date=date(2019,1,1))
# Out:
# 2021-03-30 22:07:33,545 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-03-30 22:07:33,547 INFO sqlalchemy.engine.base.Engine SELECT "Top200".id AS "Top200_id", "Top200".spotify_id AS "Top200_spotify_id", "Top200".date AS "Top200_date", "Top200".region AS "Top200_region", "Top200".position AS "Top200_position", "Top200".track_name AS "Top200_track_name", "Top200".artist AS "Top200_artist", "Top200".streams AS "Top200_streams"
# FROM "Top200"
# WHERE "Top200".region IN (?, ?) AND "Top200".date >= ?
# 2021-03-30 22:07:33,549 INFO sqlalchemy.engine.base.Engine ('us', 'pl', '2019-01-01')
# 2021-03-30 22:07:45,818 INFO sqlalchemy.engine.base.Engine ROLLBACK
# 2021-03-30 22:07:46,332 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-03-30 22:07:46,334 INFO sqlalchemy.engine.base.Engine SELECT "AudioFeatures".id AS "AudioFeatures_id", "AudioFeatures".danceability AS "AudioFeatures_danceability", "AudioFeatures".energy AS "AudioFeatures_energy", "AudioFeatures".loudness AS "AudioFeatures_loudness", "AudioFeatures".speechiness AS "AudioFeatures_speechiness", "AudioFeatures".acousticness AS "AudioFeatures_acousticness", "AudioFeatures".instrumentalness AS "AudioFeatures_instrumentalness", "AudioFeatures".liveness AS "AudioFeatures_liveness", "AudioFeatures".valence AS "AudioFeatures_valence", "AudioFeatures".tempo AS "AudioFeatures_tempo", "AudioFeatures".duration_ms AS "AudioFeatures_duration_ms"
# FROM "AudioFeatures"
# 2021-03-30 22:07:46,334 INFO sqlalchemy.engine.base.Engine ()
# 2021-03-30 22:07:50,471 INFO sqlalchemy.engine.base.Engine ROLLBACK

# %%
print(len(df))
df.head()
# Out:
# 215377
#   region              spotify_id     artist  position        date  streams  \
# 0     pl  2VxeLyX666F8uXCJ0dZF8B  Lady Gaga         1  2019-01-02    59611
# 1     pl  2VxeLyX666F8uXCJ0dZF8B  Lady Gaga         1  2019-01-06    53525
# 2     pl  2VxeLyX666F8uXCJ0dZF8B  Lady Gaga         1  2019-01-09    65839
# 3     pl  2VxeLyX666F8uXCJ0dZF8B  Lady Gaga         1  2019-01-12    63575
# 4     pl  2VxeLyX666F8uXCJ0dZF8B  Lady Gaga         1  2019-01-13    54938
#
#   track_name  speechiness  energy   tempo  liveness  acousticness  loudness  \
# 0    Shallow       0.0308   0.385  95.799     0.231         0.371    -6.362
# 1    Shallow       0.0308   0.385  95.799     0.231         0.371    -6.362
# 2    Shallow       0.0308   0.385  95.799     0.231         0.371    -6.362
# 3    Shallow       0.0308   0.385  95.799     0.231         0.371    -6.362
# 4    Shallow       0.0308   0.385  95.799     0.231         0.371    -6.362
#
#    danceability  duration_ms  valence  instrumentalness
# 0         0.572       215733    0.323               0.0
# 1         0.572       215733    0.323               0.0
# 2         0.572       215733    0.323               0.0
# 3         0.572       215733    0.323               0.0
# 4         0.572       215733    0.323               0.0
