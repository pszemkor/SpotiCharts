# %%
from modules.spoticharts import SpotiCharts
from datetime import date

# %%
sc = SpotiCharts()

# %%
df = sc.get_all_viral(country_codes=['us', 'pl'], start_date=date(2019,1,1))

# %%
df.head()
# Out:
#                spotify_id region  \
# 0  27rdGxbavYJeBphck5MZAF     pl
# 1  27rdGxbavYJeBphck5MZAF     pl
# 2  27rdGxbavYJeBphck5MZAF     pl
# 3  27rdGxbavYJeBphck5MZAF     pl
# 4  27rdGxbavYJeBphck5MZAF     pl
#
#                                         track_name       artist  position  \
# 0  Nothing Breaks Like a Heart (feat. Miley Cyrus)  Mark Ronson         1
# 1  Nothing Breaks Like a Heart (feat. Miley Cyrus)  Mark Ronson         1
# 2  Nothing Breaks Like a Heart (feat. Miley Cyrus)  Mark Ronson         1
# 3  Nothing Breaks Like a Heart (feat. Miley Cyrus)  Mark Ronson         2
# 4  Nothing Breaks Like a Heart (feat. Miley Cyrus)  Mark Ronson         2
#
#          date  danceability  loudness  acousticness  liveness    tempo  \
# 0  2019-01-03         0.601    -5.844       0.00987     0.388  114.066
# 1  2019-01-05         0.601    -5.844       0.00987     0.388  114.066
# 2  2019-01-06         0.601    -5.844       0.00987     0.388  114.066
# 3  2019-01-11         0.601    -5.844       0.00987     0.388  114.066
# 4  2019-01-12         0.601    -5.844       0.00987     0.388  114.066
#
#    speechiness  energy  instrumentalness  valence  duration_ms
# 0       0.0671   0.794          0.000001    0.244       217467
# 1       0.0671   0.794          0.000001    0.244       217467
# 2       0.0671   0.794          0.000001    0.244       217467
# 3       0.0671   0.794          0.000001    0.244       217467
# 4       0.0671   0.794          0.000001    0.244       217467

# %%
print(len(df))
df.head()

# %%
df = sc.get_all_top_200(country_codes=['us', 'pl'], start_date=date(2019,1,1))

# %%
print(len(df))
df.head()
