# %%
from fycharts.SpotifyCharts import SpotifyCharts
import numpy as np
import pandas as pd

# %%
api = SpotifyCharts()
result = api.top200Daily(output_file = "top_200_daily.csv", start = "2019-01-01", end = "2019-01-31", region = ["us", "global"])
# Out:
# INFO : 15/03/2021 04:48:22 PM : Extracting top 200 daily for 2019-01-01 - us
# INFO : 15/03/2021 04:48:23 PM : Extracting top 200 daily for 2019-01-01 - global
# INFO : 15/03/2021 04:48:23 PM : Appending data to the file top_200_daily.csv...
# INFO : 15/03/2021 04:48:23 PM : Done appending to the file top_200_daily.csv!!!
# INFO : 15/03/2021 04:48:24 PM : Extracting top 200 daily for 2019-01-02 - us
# INFO : 15/03/2021 04:48:24 PM : Appending data to the file top_200_daily.csv...
# INFO : 15/03/2021 04:48:24 PM : Done appending to the file top_200_daily.csv!!!
# INFO : 15/03/2021 04:48:26 PM : Extracting top 200 daily for 2019-01-02 - global
# INFO : 15/03/2021 04:48:26 PM : Appending data to the file top_200_daily.csv...
# INFO : 15/03/2021 04:48:26 PM : Done appending to the file top_200_daily.csv!!!
# INFO : 15/03/2021 04:48:27 PM : Extracting top 200 daily for 2019-01-03 - us
# INFO : 15/03/2021 04:48:27 PM : Appending data to the file top_200_daily.csv...
# ...

# %%
type(result)
# Out:
# NoneType
